# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
clients = pd.read_csv('./data/trinet_clients.csv', parse_dates=True)
clients.head()
# Out:
# /Users/jamesrichards/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 Company                   Company.Name              City State  \
# 0           1     4AW               HRchitect Canada            Frisco    TX
# 1           2     4B9              RouteOne - Canada  Farmington Hills    MI
# 2           3     4BJ            Ekaria LLP - Canada           Redmond    WA
# 3           4     4BY    MicroVention, Inc. - Canada       Aliso Viejo    CA
# 4           5     51Z  Signature Control Systems CAN          Sheridan    CO
#
#   Related.Company Company.Live.Date  NAICS.2  NAICS.3  NAICS.4  \
# 0             NaN         1/12/2004      NaN      NaN      NaN
# 1             NaN         2/16/2004      NaN      NaN      NaN
# ...

# %%
clients.shape
# Out:
# (9677, 119)

# %%
clients.isnull().sum()
# Out:
# Unnamed: 0                                            0
# Company                                               0
# Company.Name                                          5
# City                                                  0
# State                                                 0
# Related.Company                                    8050
# Company.Live.Date                                     0
# NAICS.2                                             139
# NAICS.3                                             139
# NAICS.4                                             139
# NAICS.5                                             139
# NAICS.6                                             139
# NAICS.2.des                                         139
# NAICS.3.des                                         148
# NAICS.4.des                                         149
# NAICS.5.des                                         151
# NAICS.6.des                                         162
# ...
